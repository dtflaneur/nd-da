# %% [markdown]
# # Project 4: Wrangle OpenStreetMap Data

# %% [markdown]
# ## Summary
#
# **Map area:**
# + Location: Mumbai India - [https://mapzen.com/data/metro-extracts/your-extracts/693a2a74b296](https://mapzen.com/data/metro-extracts/your-extracts/693a2a74b296)
#
# Objective: Audit, clean the OSM dataset, convert from XML to JSON format and analyze insight within the data.

# %% [markdown]
# ## 1. Data Audit

# %%
import xml.etree.cElementTree as ET
import pprint
import re
import codecs
import json
import collections
import pymongo

# %%
import os
datadir = "data"
datafile = "mumbai.osm"
cal_data = os.path.join(datadir, datafile)

# %% [markdown]
# function count_tags will parse through Mumbai dataset with ElementTree and count the number of unique elements to get an overview of the data and use pretty print to print the results.

# %%
def count_tags(filename):
        tags = {}
        for event, elem in ET.iterparse(filename):
            if elem.tag in tags: 
                tags[elem.tag] += 1
            else:
                tags[elem.tag] = 1
        return tags
cal_tags = count_tags(cal_data)
pprint.pprint(cal_tags)
# Out:
# {'bounds': 1,
#  'member': 1842,
#  'nd': 307388,
#  'node': 262994,
#  'osm': 1,
#  'relation': 585,
#  'tag': 75186,
#  'way': 40296}

# %% [markdown]
# For following functions: key_type & process_map. We check the "k" value for each tag and see if they can be valid keys in MongoDB, as well as see if there are any other potential problems. As we saw in the quiz earlier, we would like to change the data model and expand the "addr:street" type of keys to a dictionary like this:
# {"address": {"street": "Some value"}}
# So, we have to see if we have such tags, and if we have any tags with problematic characters.

# %%
import re

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

# %%
def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter('tag'):
            k = tag.get('k')
            if lower.search(k):
                keys['lower'] += 1
            elif lower_colon.search(k):
                keys['lower_colon'] += 1
            elif problemchars.search(k):
                keys['problemchars'] += 1
            else:
                keys['other'] += 1
    return keys

# %% [markdown]
# For the function 'key_type', we have a count of each of three tag categories in a dictionary:
#   - "lower", for tags that contain only lowercase letters and are valid,
#   - "lower_colon", for otherwise valid tags with a colon in their names,
#   - "problemchars", for tags with problematic characters

# %%
def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

cal_keys = process_map(cal_data)
pprint.pprint(cal_keys)
# Out:
# {'lower': 68019, 'lower_colon': 7069, 'other': 97, 'problemchars': 1}

# %% [markdown]
# find how many unique users have contributed to the map editing.

# %%
#people invovlved in the map editing.
def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        for e in element:
            if 'uid' in e.attrib:
                users.add(e.attrib['uid'])
    return users
users = process_map(cal_data)
len(users)
# Out:
# 783

# %% [markdown]
# ## 2. Problems encountered

# %% [markdown]
# <h3><a name="street"></a> **2.1 Street address abbreviation **</h3>

# %% [markdown]
# One of the problem is the street name abbreviation inconsistency. Below we make the regex matching the last element in the string, where usually the street type is based.

# %%
from collections import defaultdict

street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Road"]
mapping = {'Rd'   : 'Road',
           'Rd.'   : 'Road',
           'road'   : 'Road',
           'road No.' :"Road",
           'Road No.' :"Road",
           }

# %% [markdown]
# + audit_street_type function search the input string for the regex. If there is a match and it is not within the "expected" list, add the match as a key and add the string to the set.

# %%
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

# %% [markdown]
# + is_street_name function looks at the attribute k if k="addre:street"

# %%
def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

# %% [markdown]
# + audit function will return the list that match previous two functions. After that, we would do a pretty print the output of the audit. With the list of all the abbreviated street types we can understand and fill-up our "mapping" dictionary.

# %%
def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types
cal_street_types = audit(cal_data)
pprint.pprint(dict(cal_street_types))
# Out:
# {'1': set(['Road No 1']),
#  '10': set(['Road No 10']),
#  '13': set(['Road No 13', 'Road No. 13', 'road No. 13']),
#  '19': set(['Road No 19']),
#  '2': set(['L. J. Cross Road No. 2', 'Road No 2', 'Road Number 2']),
#  '25': set(['Road No 25']),
#  '26': set(['Road No 26']),
#  '3': set(['Road No 3', 'Road Number 3']),
#  '4': set(['RCF Colony Type 4', 'Road No 4', 'Road Number 4']),
#  '5': set(['Road Number 5']),
#  '8': set(['Road No. 8']),
#  '9': set(['Road No. 9']),
#  'Avenue)': set(['D Saraswati Marg (Central Avenue)']),
#  'Baug': set(['Saras Baug']),
#  'Bhavan': set(['Vidhan Bhavan']),
#  'Bridge': set(['A Irani Bridge', 'Elphinstone Bridge']),
#  'COLONY': set(['P.L. Lokhande Marg,MHADA COLONY', 'THAKKAR BAPPA COLONY']),
#  'CST': set(['Bora Bazaar Street, Siddhi Vinayak CHS, Fort, CST']),
#  'Chawl': set(['Sutar Chawl']),
#  'Chembur': set(['Amar Mahal , Chembur', 'Tilak Nagar, Chembur']),
#  'Chowk': set(['Doctor Shyama Prasad Mukherjee Chowk']),
#  'Colony': set(['Mysore Colony', 'R.C.F. Colony', 'RCF Colony']),
#  'Complex': set(['Wockhardt Towers, East Wing, 5th Floor, Bandra Kurla Complex']),
#  'Compound': set(["St. George's Hospital Compound"]),
#  'Deonar': set(['Near Dukes Factory, Waman Tukaram Patil Marg (Ghatkopar Sewri Wadala Road), Deonar',
#                 'Sion Trombay Road, Deonar']),
#  'Drive': set(['Marine Drive']),
#  'East': set(['Com. Harbanslal Marg, Sion East', 'Kher Nagar, Bandra East']),
#  'East)': set(['Bandra (East)']),
#  'Estate': set(['Sport Road, Ballard Estate']),
#  'FOB': set(['Govandi FOB']),
#  'Flyover': set(["King's Circle Flyover", 'Marine Lines Flyover']),
#  'Highway': set(['Eastern Express Highway']),
#  'III': set(['23rd Road, T.P.S. III',
#              '28th Road,  T.P.S. III',
#              '28th Road, T.P.S. III',
#              '28th Road, TPS III',
#              "Jn. of 28th Road & St. Theresa's Road, T.P.S. III"]),
#  'Kalbadevi': set(['Kalbadevi']),
#  'Lane': set(['14th Lane',
#               '1st Pasta Lane',
#               '4th Pasta Lane',
#               'Dontad Cross Lane',
#               'Ice Factory Lane',
#               'Khetwadi 12th Lane',
#               'Khetwadi 5th Lane',
#               'Sadashiva Cross Lane',
#               'Sindhi Lane',
#               "St. Anne's Lane"]),
#  'Lane)': set(['Khadilkar Marg (Kandewadi Lane)']),
#  'Lines': set(['New Marine Lines']),
#  'Maharashtra': set(['90/ A, Near Holy Family Hospital, Hill Rd, Bandra West, Mumbai, Maharashtra']),
#  'Mandal': set(['Gokhale Road North, Amarhind Mandal']),
#  'Marg': set(['A H Wadia Marg',
#               'Abaji Marg',
#               'Amit Keshav Nayak Marg',
#               'Appasaheb Marathe Marg',
#               'B D Patil Marg',
#               'Balshet Madurkar Marg',
#               'Bhikoba Waman Pathare Marg',
#               'Captain Prakash Pethe Marg',
#               'D K Sandu Marg',
#               'Dadasaheb Phalke Marg',
#               'Dr Babasaheb Ambedkar Marg',
#               'Dr Madhukar B. Raut Marg',
#               'G Talwarkar Marg',
#               'G.D. Ambedkar Marg',
#               'Ganapatrao Kadam Marg',
#               'Gopi Tank Marg',
#               'Gurunanak Marg',
#               'Jagannath Shankarsheth Marg',
#               'Javji Dadaji Marg',
#               'Jeejabai Bhosle Marg',
#               'K C Marg',
#               'Kadeshwari Marg',
#               'Keshavrao Khadye Marg',
#               'Laxman Umaji Gadkari Marg',
#               'Lockmanya Talik Marg',
#               'Madhusudan Kalekar Marg',
#               'Madhusudhan Kalelkar Marg',
#               'Maulana Shaukat Ali Marg',
#               'Mumbai Samachar Marg',
#               'N Bharucha Marg',
#               'N Dharmadhikari Marg',
#               'N M Joshi Marg',
#               'N.M Joshi Marg',
#               'P Ramabai Marg',
#               'P.L. Lokhande Marg',
#               'PG Kher Marg',
#               'Pandit Madan Mohan Malviya Marg',
#               'Pandurang Budhkar Marg',
#               'Pradip Dattatra Samant Marg',
#               'Pradip Dattatraya Samant Marg',
#               'Prakash Pethe Marg',
#               'Prakash Thorat Marg',
#               'R N Goenka Marg',
#               'Rajendra Venkateshwara Rao Marg',
#               'Ramakrishna Chemburkar Marg',
#               'Rao Khadye Marg',
#               'SL Raheja Hospital Marg',
#               'Sant Savta Mali Marg',
#               'Senapati Bapat Marg',
#               'Shahid Bhagat Singh Marg',
#               'Shankar Ghanekar Marg',
#               'Sharadbhau Acharya Marg',
#               'Sivram Seth Amritwar Marg',
#               'Sulochana Shetty Marg',
#               'Swami Gyan Jiwandas Marg',
#               'Swatantrya Veer Savarkar Marg',
#               'Tukaram Javji Marg',
#               'V N Purav Marg',
#               'V. N. Purav Marg',
#               'Waman Tukaram Patil Marg',
#               'm Ambedkar Marg']),
#  'Marg)': set(['26th Road (Sumatilal Manilal Shah Marg)',
#                '27th Road (Pandurang Ashram Marg)',
#                'Sion Panvel Highway (Yashwantrao Chavan Marg)',
#                'Turner Road (Gurunanak Marg)']),
#  'Marg,': set(['JK Sawant Marg,']),
#  'Mumbai': set(['Hindcycle Road, Worli, Mumbai']),
#  'Nagar': set(['Chheda Nagar', 'General Arun Kumar Vaidya Nagar']),
#  'Naoroji': set(['Dr. Dadabhai Naoroji']),
#  'New': set([', Shubhada Building, Firstfloor, Sir Pochkhanwala Road, Worli New']),
#  'No.1': set(['L.J. Road No.1']),
#  'No.2': set(['Plot No.2']),
#  'North': set(['Gokhale Road North']),
#  'Path': set(['Adi Murzban Path',
#               'Gregorios Path',
#               'Lt Prakash Kotnis Path',
#               'Nagdevi Path']),
#  'Point': set(['Backbay Reclamation, Nariman Point', 'Nariman Point']),
#  'ROAD': set(['SION TROMBAY ROAD']),
#  'Ranwar': set(['Hill Road, Ranwar']),
#  'Rd': set(['35th Rd',
#             'Carmichael Rd',
#             'Mavla Maratha Rd',
#             'NL Rd',
#             'Vishnu Nagar Rd',
#             'Wodehouse Rd',
#             'vishnu Nagar Rd']),
#  'Restauran': set([', Off Hemu Kalani Marg, Chembur East, Mumbai - 400071, Behind Maruti Suzuki Showroom, Behind Ankit Chinese Restauran']),
#  'Road)': set(['Allibhai Premji Marg (Foras Road)',
#                'Bhikaji Damaji Patil Marg (Corridor Road)',
#                'Boman Behram Road (Mere Weather Road)',
#                'Choitram Gidwani Marg (Kolwada Borla Road)',
#                'Dr Annie Besant Road (Love Grove Road)',
#                'Dr Baba Saheb Ambedkar Marg (Victoria Garden Road)',
#                'Dr Babasaheb Ambedkar Marg (Vincent Road)',
#                'Dr KS Hedgewar Road (30th Road)',
#                'J Boman Behram Marg (Bellasis Road)',
#                'Krishna Chandra Road (Hill Road)',
#                'Maratha Mandir Marg (Club Road)',
#                'Master Vinayak Road (Perry Road)',
#                'N G Acharya Marg (Chembur Govandi Road)',
#                'N M Joshi Marg (Delsle Road)',
#                'Nanabhai Moos Marg (Upper Colaba Road)',
#                'Nathalal M. Parikh Road (Wodehouse Road)',
#                'PD Hinduja Road (Khar Pali Road)',
#                'Patthe Bapurao Marg (Falkland Road)',
#                'RK Patkar Marg (Waterfield Road)',
#                'Raja Ram Mohan Roy Road (Charni Road)',
#                'Ramakrishna Chemburkar Marg (Ghatkopar Mahul Road)',
#                'Ramdas Naik Road (Hill Road)',
#                'Ramjibhai Kamani Road (Nichol Road)',
#                'S B Dhody Marg (Nesbit Road)',
#                'Sardar Vallabhbhai Patel Marg (Sandhurst Road)',
#                'Senapati Bapat Marg (Tulsi Pipe Road)',
#                'Shahid Bhagat Singh Marg (Lower Colaba Road)',
#                'Sitram Jadhav Marg (Sun Mill Road)',
#                'V N Purav Marg (Sion Trombay Road)',
#                'Vithalbhai Patel Road (Linking Road)',
#                'YMCA Road (Club Back Road)']),
#  'Society': set(['Sindhi Society']),
#  'Street': set(['Cawasji Patel Street',
#                 'Dadiseth Agiary Street',
#                 'Dalal Street',
#                 'Kalyan Street',
#                 'Lamington Street',
#                 'Nowroji Ferdonji Street',
#                 'Perin Nariman Street',
#                 'Rope Walk Street',
#                 "Saint John's Street",
#                 'Sarang Street',
#                 'St Dominic Street',
#                 "St John's Street",
#                 'Tantanpura Street',
#                 'Wallace Street']),
#  'Street)': set(['Veer Vithaldas Chandan Street (De Souza Street)']),
#  'Wadala': set(['Jain Derasar Road, Wadala']),
#  'Wadi': set(['Kele Wadi', 'Kotachi Wadi', 'Navi Wadi', 'Zaoba Wadi']),
#  'West': set(['16th Road, Bandra West',
#               'Dr Ambedkar Road, Bandra West',
#               'Dr B.R Ambedkar Road, Bandra West',
#               'Dr BR Ambedkar Road, Bandra West',
#               'Hill Road, Bandra West',
#               'Linking Road, Bandra West',
#               'Pali Junction, Dr BR Ambedkar Road, Bandra West',
#               'Pali Market Road, Bandra West',
#               'St Alexius Road, Bandra West',
#               "St Cyril's Road, Bandra West",
#               "St John's Road, Bandra West",
#               "St John's Street, Bandra West"]),
#  'West)': set(['Jaishankar Yagnik Road (Flank Road West)']),
#  'baingawadi': set(['Road no 9 baingawadi']),
#  'circle': set(['jacob circle']),
#  'colony': set(['railway colony']),
#  'compound': set(['lalluabai compound']),
#  'govandi': set(['govandi']),
#  'kurla': set(['kurla']),
#  'l.j.road': set(['l.j.road']),
#  'lane': set(['Bhagat lane', 'T.H. Karatia Marg, Mogul lane']),
#  'mansion': set(['Kamal mansion']),
#  'marg': set(['H.N.A azmi marg',
#               'Near dwarka shop p.l.lokhande marg',
#               'P L Lokhande marg',
#               'gokul marg',
#               'm ward marg',
#               'sitaram palturam murai marg',
#               'vidyarthi marg']),
#  'no.1': set(['Road no.1']),
#  'no.10': set(['Scheme 57 Road no.10']),
#  'no.13': set(['road no.13']),
#  'no.3': set(['Dada Rege Marg aka. Shivaji Park Road no.3']),
#  'path': set(['datta mandhiar foot path']),
#  'road': set(['24th road',
#               '2nd floor swadesi market kalbadevi road',
#               '90 feet road',
#               'Harbour Heights service road',
#               'Manish Market service road',
#               'ghatkapar/mankhurd link road',
#               'l.u.gadkari road',
#               'market road',
#               'mohd ali road',
#               'mohmmad road',
#               'video road']),
#  'road,Sion-chunabhatti': set(['hill road,Sion-chunabhatti']),
#  'stn': set(['chembur stn']),
#  'street': set(['c.s.t street', 'khandia street'])}

# %% [markdown]
# function update_name takes the old name and update them with a better name

# %%
def update_name(name, mapping, regex):
    m = regex.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = re.sub(regex, mapping[street_type], name)

    return name

for street_type, ways in cal_street_types.iteritems():
    for name in ways:
        better_name = update_name(name, mapping, street_type_re)
        print name, "=>", better_name
# Out:
# D Saraswati Marg (Central Avenue) => D Saraswati Marg (Central Avenue)
# Laxman Umaji Gadkari Marg => Laxman Umaji Gadkari Marg
# Dr Madhukar B. Raut Marg => Dr Madhukar B. Raut Marg
# Dr Babasaheb Ambedkar Marg => Dr Babasaheb Ambedkar Marg
# V N Purav Marg => V N Purav Marg
# Lockmanya Talik Marg => Lockmanya Talik Marg
# Shahid Bhagat Singh Marg => Shahid Bhagat Singh Marg
# Keshavrao Khadye Marg => Keshavrao Khadye Marg
# R N Goenka Marg => R N Goenka Marg
# Pradip Dattatra Samant Marg => Pradip Dattatra Samant Marg
# Jagannath Shankarsheth Marg => Jagannath Shankarsheth Marg
# D K Sandu Marg => D K Sandu Marg
# Sulochana Shetty Marg => Sulochana Shetty Marg
# G.D. Ambedkar Marg => G.D. Ambedkar Marg
# Abaji Marg => Abaji Marg
# Tukaram Javji Marg => Tukaram Javji Marg
# Prakash Thorat Marg => Prakash Thorat Marg
# K C Marg => K C Marg
# Pandurang Budhkar Marg => Pandurang Budhkar Marg
# Pradip Dattatraya Samant Marg => Pradip Dattatraya Samant Marg
# Amit Keshav Nayak Marg => Amit Keshav Nayak Marg
# N.M Joshi Marg => N.M Joshi Marg
# Ganapatrao Kadam Marg => Ganapatrao Kadam Marg
# Rajendra Venkateshwara Rao Marg => Rajendra Venkateshwara Rao Marg
# G Talwarkar Marg => G Talwarkar Marg
# Ramakrishna Chemburkar Marg => Ramakrishna Chemburkar Marg
# Madhusudan Kalekar Marg => Madhusudan Kalekar Marg
# m Ambedkar Marg => m Ambedkar Marg
# Sivram Seth Amritwar Marg => Sivram Seth Amritwar Marg
# Bhikoba Waman Pathare Marg => Bhikoba Waman Pathare Marg
# V. N. Purav Marg => V. N. Purav Marg
# Shankar Ghanekar Marg => Shankar Ghanekar Marg
# Swatantrya Veer Savarkar Marg => Swatantrya Veer Savarkar Marg
# Swami Gyan Jiwandas Marg => Swami Gyan Jiwandas Marg
# N Dharmadhikari Marg => N Dharmadhikari Marg
# N M Joshi Marg => N M Joshi Marg
# Maulana Shaukat Ali Marg => Maulana Shaukat Ali Marg
# Pandit Madan Mohan Malviya Marg => Pandit Madan Mohan Malviya Marg
# Waman Tukaram Patil Marg => Waman Tukaram Patil Marg
# Sharadbhau Acharya Marg => Sharadbhau Acharya Marg
# Rao Khadye Marg => Rao Khadye Marg
# Balshet Madurkar Marg => Balshet Madurkar Marg
# Gopi Tank Marg => Gopi Tank Marg
# Sant Savta Mali Marg => Sant Savta Mali Marg
# N Bharucha Marg => N Bharucha Marg
# Dadasaheb Phalke Marg => Dadasaheb Phalke Marg
# B D Patil Marg => B D Patil Marg
# SL Raheja Hospital Marg => SL Raheja Hospital Marg
# Mumbai Samachar Marg => Mumbai Samachar Marg
# Appasaheb Marathe Marg => Appasaheb Marathe Marg
# P.L. Lokhande Marg => P.L. Lokhande Marg
# Prakash Pethe Marg => Prakash Pethe Marg
# Gurunanak Marg => Gurunanak Marg
# PG Kher Marg => PG Kher Marg
# Captain Prakash Pethe Marg => Captain Prakash Pethe Marg
# Javji Dadaji Marg => Javji Dadaji Marg
# Madhusudhan Kalelkar Marg => Madhusudhan Kalelkar Marg
# A H Wadia Marg => A H Wadia Marg
# Kadeshwari Marg => Kadeshwari Marg
# P Ramabai Marg => P Ramabai Marg
# Jeejabai Bhosle Marg => Jeejabai Bhosle Marg
# Senapati Bapat Marg => Senapati Bapat Marg
# Govandi FOB => Govandi FOB
# Hindcycle Road, Worli, Mumbai => Hindcycle Road, Worli, Mumbai
# Dr BR Ambedkar Road, Bandra West => Dr BR Ambedkar Road, Bandra West
# St John's Road, Bandra West => St John's Road, Bandra West
# 16th Road, Bandra West => 16th Road, Bandra West
# Pali Market Road, Bandra West => Pali Market Road, Bandra West
# St John's Street, Bandra West => St John's Street, Bandra West
# Hill Road, Bandra West => Hill Road, Bandra West
# Pali Junction, Dr BR Ambedkar Road, Bandra West => Pali Junction, Dr BR Ambedkar Road, Bandra West
# Dr B.R Ambedkar Road, Bandra West => Dr B.R Ambedkar Road, Bandra West
# Dr Ambedkar Road, Bandra West => Dr Ambedkar Road, Bandra West
# St Alexius Road, Bandra West => St Alexius Road, Bandra West
# Linking Road, Bandra West => Linking Road, Bandra West
# St Cyril's Road, Bandra West => St Cyril's Road, Bandra West
# lalluabai compound => lalluabai compound
# railway colony => railway colony
# Amar Mahal , Chembur => Amar Mahal , Chembur
# Tilak Nagar, Chembur => Tilak Nagar, Chembur
# Sindhi Society => Sindhi Society
# vishnu Nagar Rd => vishnu Nagar Road
# Carmichael Rd => Carmichael Road
# Wodehouse Rd => Wodehouse Road
# NL Rd => NL Road
# Mavla Maratha Rd => Mavla Maratha Road
# Vishnu Nagar Rd => Vishnu Nagar Road
# 35th Rd => 35th Road
# Wockhardt Towers, East Wing, 5th Floor, Bandra Kurla Complex => Wockhardt Towers, East Wing, 5th Floor, Bandra Kurla Complex
# Khadilkar Marg (Kandewadi Lane) => Khadilkar Marg (Kandewadi Lane)
# Vidhan Bhavan => Vidhan Bhavan
# datta mandhiar foot path => datta mandhiar foot path
# Kamal mansion => Kamal mansion
# Gokhale Road North, Amarhind Mandal => Gokhale Road North, Amarhind Mandal
# Kher Nagar, Bandra East => Kher Nagar, Bandra East
# Com. Harbanslal Marg, Sion East => Com. Harbanslal Marg, Sion East
# hill road,Sion-chunabhatti => hill road,Sion-chunabhatti
# Road No 25 => Road No 25
# YMCA Road (Club Back Road) => YMCA Road (Club Back Road)
# Bhikaji Damaji Patil Marg (Corridor Road) => Bhikaji Damaji Patil Marg (Corridor Road)
# Sardar Vallabhbhai Patel Marg (Sandhurst Road) => Sardar Vallabhbhai Patel Marg (Sandhurst Road)
# J Boman Behram Marg (Bellasis Road) => J Boman Behram Marg (Bellasis Road)
# PD Hinduja Road (Khar Pali Road) => PD Hinduja Road (Khar Pali Road)
# Sitram Jadhav Marg (Sun Mill Road) => Sitram Jadhav Marg (Sun Mill Road)
# N G Acharya Marg (Chembur Govandi Road) => N G Acharya Marg (Chembur Govandi Road)
# S B Dhody Marg (Nesbit Road) => S B Dhody Marg (Nesbit Road)
# Boman Behram Road (Mere Weather Road) => Boman Behram Road (Mere Weather Road)
# Maratha Mandir Marg (Club Road) => Maratha Mandir Marg (Club Road)
# V N Purav Marg (Sion Trombay Road) => V N Purav Marg (Sion Trombay Road)
# Dr KS Hedgewar Road (30th Road) => Dr KS Hedgewar Road (30th Road)
# Allibhai Premji Marg (Foras Road) => Allibhai Premji Marg (Foras Road)
# Dr Babasaheb Ambedkar Marg (Vincent Road) => Dr Babasaheb Ambedkar Marg (Vincent Road)
# Krishna Chandra Road (Hill Road) => Krishna Chandra Road (Hill Road)
# N M Joshi Marg (Delsle Road) => N M Joshi Marg (Delsle Road)
# Shahid Bhagat Singh Marg (Lower Colaba Road) => Shahid Bhagat Singh Marg (Lower Colaba Road)
# Nanabhai Moos Marg (Upper Colaba Road) => Nanabhai Moos Marg (Upper Colaba Road)
# Nathalal M. Parikh Road (Wodehouse Road) => Nathalal M. Parikh Road (Wodehouse Road)
# Ramjibhai Kamani Road (Nichol Road) => Ramjibhai Kamani Road (Nichol Road)
# Dr Annie Besant Road (Love Grove Road) => Dr Annie Besant Road (Love Grove Road)
# Ramakrishna Chemburkar Marg (Ghatkopar Mahul Road) => Ramakrishna Chemburkar Marg (Ghatkopar Mahul Road)
# Dr Baba Saheb Ambedkar Marg (Victoria Garden Road) => Dr Baba Saheb Ambedkar Marg (Victoria Garden Road)
# Vithalbhai Patel Road (Linking Road) => Vithalbhai Patel Road (Linking Road)
# Master Vinayak Road (Perry Road) => Master Vinayak Road (Perry Road)
# Ramdas Naik Road (Hill Road) => Ramdas Naik Road (Hill Road)
# Senapati Bapat Marg (Tulsi Pipe Road) => Senapati Bapat Marg (Tulsi Pipe Road)
# Patthe Bapurao Marg (Falkland Road) => Patthe Bapurao Marg (Falkland Road)
# Raja Ram Mohan Roy Road (Charni Road) => Raja Ram Mohan Roy Road (Charni Road)
# RK Patkar Marg (Waterfield Road) => RK Patkar Marg (Waterfield Road)
# Choitram Gidwani Marg (Kolwada Borla Road) => Choitram Gidwani Marg (Kolwada Borla Road)
# m ward marg => m ward marg
# vidyarthi marg => vidyarthi marg
# sitaram palturam murai marg => sitaram palturam murai marg
# H.N.A azmi marg => H.N.A azmi marg
# P L Lokhande marg => P L Lokhande marg
# Near dwarka shop p.l.lokhande marg => Near dwarka shop p.l.lokhande marg
# gokul marg => gokul marg
# Gokhale Road North => Gokhale Road North
# Bandra (East) => Bandra (East)
# Road No 1 => Road No 1
# Near Dukes Factory, Waman Tukaram Patil Marg (Ghatkopar Sewri Wadala Road), Deonar => Near Dukes Factory, Waman Tukaram Patil Marg (Ghatkopar Sewri Wadala Road), Deonar
# Sion Trombay Road, Deonar => Sion Trombay Road, Deonar
# Road No 3 => Road No 3
# Road Number 3 => Road Number 3
# Sarang Street => Sarang Street
# Kalyan Street => Kalyan Street
# Dalal Street => Dalal Street
# Tantanpura Street => Tantanpura Street
# St John's Street => St John's Street
# Saint John's Street => Saint John's Street
# Rope Walk Street => Rope Walk Street
# Dadiseth Agiary Street => Dadiseth Agiary Street
# St Dominic Street => St Dominic Street
# Lamington Street => Lamington Street
# Perin Nariman Street => Perin Nariman Street
# Wallace Street => Wallace Street
# Cawasji Patel Street => Cawasji Patel Street
# Nowroji Ferdonji Street => Nowroji Ferdonji Street
# Road Number 5 => Road Number 5
# Road Number 4 => Road Number 4
# RCF Colony Type 4 => RCF Colony Type 4
# Road No 4 => Road No 4
# kurla => kurla
# St. George's Hospital Compound => St. George's Hospital Compound
# Road No. 9 => Road No. 9
# Nagdevi Path => Nagdevi Path
# Gregorios Path => Gregorios Path
# Adi Murzban Path => Adi Murzban Path
# Lt Prakash Kotnis Path => Lt Prakash Kotnis Path
# jacob circle => jacob circle
# Jn. of 28th Road & St. Theresa's Road, T.P.S. III => Jn. of 28th Road & St. Theresa's Road, T.P.S. III
# 23rd Road, T.P.S. III => 23rd Road, T.P.S. III
# 28th Road,  T.P.S. III => 28th Road,  T.P.S. III
# 28th Road, T.P.S. III => 28th Road, T.P.S. III
# 28th Road, TPS III => 28th Road, TPS III
# Hill Road, Ranwar => Hill Road, Ranwar
# SION TROMBAY ROAD => SION TROMBAY ROAD
# Road No 26 => Road No 26
# Kalbadevi => Kalbadevi
# Dada Rege Marg aka. Shivaji Park Road no.3 => Dada Rege Marg aka. Shivaji Park Road no.3
# St. Anne's Lane => St. Anne's Lane
# Khetwadi 12th Lane => Khetwadi 12th Lane
# Sadashiva Cross Lane => Sadashiva Cross Lane
# Dontad Cross Lane => Dontad Cross Lane
# Ice Factory Lane => Ice Factory Lane
# Khetwadi 5th Lane => Khetwadi 5th Lane
# 14th Lane => 14th Lane
# Sindhi Lane => Sindhi Lane
# 4th Pasta Lane => 4th Pasta Lane
# 1st Pasta Lane => 1st Pasta Lane
# c.s.t street => c.s.t street
# khandia street => khandia street
# Eastern Express Highway => Eastern Express Highway
# Road No 10 => Road No 10
# THAKKAR BAPPA COLONY => THAKKAR BAPPA COLONY
# P.L. Lokhande Marg,MHADA COLONY => P.L. Lokhande Marg,MHADA COLONY
# Bora Bazaar Street, Siddhi Vinayak CHS, Fort, CST => Bora Bazaar Street, Siddhi Vinayak CHS, Fort, CST
# Jaishankar Yagnik Road (Flank Road West) => Jaishankar Yagnik Road (Flank Road West)
# New Marine Lines => New Marine Lines
# Road no 9 baingawadi => Road no 9 baingawadi
# King's Circle Flyover => King's Circle Flyover
# Marine Lines Flyover => Marine Lines Flyover
# Marine Drive => Marine Drive
# Saras Baug => Saras Baug
# Plot No.2 => Plot No.2
# L.J. Road No.1 => L.J. Road No.1
# Doctor Shyama Prasad Mukherjee Chowk => Doctor Shyama Prasad Mukherjee Chowk
# Road No 2 => Road No 2
# Road Number 2 => Road Number 2
# L. J. Cross Road No. 2 => L. J. Cross Road No. 2
# , Off Hemu Kalani Marg, Chembur East, Mumbai - 400071, Behind Maruti Suzuki Showroom, Behind Ankit Chinese Restauran => , Off Hemu Kalani Marg, Chembur East, Mumbai - 400071, Behind Maruti Suzuki Showroom, Behind Ankit Chinese Restauran
# 90/ A, Near Holy Family Hospital, Hill Rd, Bandra West, Mumbai, Maharashtra => 90/ A, Near Holy Family Hospital, Hill Rd, Bandra West, Mumbai, Maharashtra
# Road No. 13 => Road No. 13
# road No. 13 => road No. 13
# Road No 13 => Road No 13
# govandi => govandi
# road no.13 => road no.13
# A Irani Bridge => A Irani Bridge
# Elphinstone Bridge => Elphinstone Bridge
# T.H. Karatia Marg, Mogul lane => T.H. Karatia Marg, Mogul lane
# Bhagat lane => Bhagat lane
# Scheme 57 Road no.10 => Scheme 57 Road no.10
# Sport Road, Ballard Estate => Sport Road, Ballard Estate
# Nariman Point => Nariman Point
# Backbay Reclamation, Nariman Point => Backbay Reclamation, Nariman Point
# , Shubhada Building, Firstfloor, Sir Pochkhanwala Road, Worli New => , Shubhada Building, Firstfloor, Sir Pochkhanwala Road, Worli New
# chembur stn => chembur stn
# RCF Colony => RCF Colony
# R.C.F. Colony => R.C.F. Colony
# Mysore Colony => Mysore Colony
# General Arun Kumar Vaidya Nagar => General Arun Kumar Vaidya Nagar
# Chheda Nagar => Chheda Nagar
# Road No 19 => Road No 19
# Jain Derasar Road, Wadala => Jain Derasar Road, Wadala
# Dr. Dadabhai Naoroji => Dr. Dadabhai Naoroji
# l.j.road => l.j.road
# Zaoba Wadi => Zaoba Wadi
# Kotachi Wadi => Kotachi Wadi
# Kele Wadi => Kele Wadi
# Navi Wadi => Navi Wadi
# Road no.1 => Road no.1
# 26th Road (Sumatilal Manilal Shah Marg) => 26th Road (Sumatilal Manilal Shah Marg)
# 27th Road (Pandurang Ashram Marg) => 27th Road (Pandurang Ashram Marg)
# Turner Road (Gurunanak Marg) => Turner Road (Gurunanak Marg)
# Sion Panvel Highway (Yashwantrao Chavan Marg) => Sion Panvel Highway (Yashwantrao Chavan Marg)
# Sutar Chawl => Sutar Chawl
# JK Sawant Marg, => JK Sawant Marg,
# Veer Vithaldas Chandan Street (De Souza Street) => Veer Vithaldas Chandan Street (De Souza Street)
# 2nd floor swadesi market kalbadevi road => 2nd floor swadesi market kalbadevi Road
# mohmmad road => mohmmad Road
# ghatkapar/mankhurd link road => ghatkapar/mankhurd link Road
# Harbour Heights service road => Harbour Heights service Road
# Manish Market service road => Manish Market service Road
# 24th road => 24th Road
# video road => video Road
# l.u.gadkari road => l.u.gadkari Road
# mohd ali road => mohd ali Road
# market road => market Road
# 90 feet road => 90 feet Road
# Road No. 8 => Road No. 8

# %% [markdown]
# <h3><a name="postal"></a> **2.2 Zip codes **</h3>

# %% [markdown]
# We can reuse part of the code above to clean the zipcodes.

# %%
from collections import defaultdict

def audit_zipcode(invalid_zipcodes, zipcode):
    twoDigits = zipcode[0:2]
    
    if not twoDigits.isdigit():
        invalid_zipcodes[twoDigits].add(zipcode)
    
    elif twoDigits != 95:
        invalid_zipcodes[twoDigits].add(zipcode)
        
def is_zipcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit_zip(osmfile):
    osm_file = open(osmfile, "r")
    invalid_zipcodes = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_zipcode(invalid_zipcodes,tag.attrib['v'])

    return invalid_zipcodes

cal_zipcode = audit_zip(cal_data)

# %%
pprint.pprint(dict(cal_zipcode))
# Out:
# {'11': set(['110092']),
#  '12': set(['123']),
#  '40': set(['400 021',
#             '400 022',
#             '400 051',
#             '400 071',
#             '400001',
#             '400002',
#             '400003',
#             '400004',
#             '400005',
#             '400007',
#             '400008',
#             '400009',
#             '40001',
#             '400010',
#             '400011',
#             '400012',
#             '400013',
#             '400014',
#             '400015',
#             '400016',
#             '400017',
#             '400018',
#             '400019',
#             '400020',
#             '400021',
#             '400022',
#             '400023',
#             '400024',
#             '400025',
#             '400027',
#             '400028',
#             '400030',
#             '400031',
#             '400033',
#             '400034',
#             '400036',
#             '400037',
#             '400038',
#             '400039',
#             '400043',
#             '400050',
#             '400051',
#             '400070',
#             '400071',
#             '400074',
#             '400088',
#             '400089',
#             '400094',
#             '400098',
#             '40051',
#             '400950'])}

# %% [markdown]
# The output of the clean zip code is below.

# %%
def update_name(zipcode):
    testNum = re.findall('[a-zA-Z]*', zipcode)
    if testNum:
        testNum = testNum[0]
    testNum.strip()
    if testNum == "CA":
        convertedZipcode = (re.findall(r'\d+', zipcode))
        if convertedZipcode:
            if convertedZipcode.__len__() == 2:
                return (re.findall(r'\d+', zipcode))[0] + "-" +(re.findall(r'\d+', zipcode))[1]
            else:
                return (re.findall(r'\d+', zipcode))[0]

for street_type, ways in cal_zipcode.iteritems():
    for name in ways:
        better_name = update_name(name)
        print name, "=>", better_name
# Out:
# 110092 => None
# 123 => None
# 400012 => None
# 400088 => None
# 400089 => None
# 400 021 => None
# 400 022 => None
# 400024 => None
# 400025 => None
# 400027 => None
# 400020 => None
# 400021 => None
# 400022 => None
# 400023 => None
# 400070 => None
# 400028 => None
# 400008 => None
# 400009 => None
# 400043 => None
# 400002 => None
# 400003 => None
# 400001 => None
# 400007 => None
# 400004 => None
# 400005 => None
# 40001 => None
# 400017 => None
# 40051 => None
# 400094 => None
# 400 071 => None
# 400098 => None
# 400033 => None
# 400031 => None
# 400030 => None
# 400037 => None
# 400036 => None
# 400034 => None
# 400039 => None
# 400038 => None
# 400 051 => None
# 400019 => None
# 400018 => None
# 400051 => None
# 400050 => None
# 400011 => None
# 400010 => None
# 400013 => None
# 400074 => None
# 400015 => None
# 400014 => None
# 400071 => None
# 400016 => None
# 400950 => None

# %% [markdown]
# ##### Preparing for MongoDB by converting XML to JSON

# %% [markdown]
# To transform the data from XML to JSON, we should follow these rules:
# + Process only 2 types of top level tags: "node" and "way"
# + All attributes of "node" and "way" should be turned into regular key/value pairs, except: attributes in the CREATED array should be added under a key "created", attributes for latitude and longitude should be added to a "pos" array, for use in geospacial indexing. Make sure the values inside "pos" array are floats and not strings.
# + If second level tag "k" value contains problematic characters, it should be ignored
# + If second level tag "k" value starts with "addr:", it should be added to a dictionary "address"
# + If second level tag "k" value does not start with "addr:", but contains ":", process it same as any other tag.
# + If there is a second ":" that separates the type/direction of a street, ignore this tag
#
# After all the cleaning is done, we use process_map function to convert the file from XML into JSON.

# %%
import re
import codecs
import json

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')
address_regex = re.compile(r'^addr\:')
street_regex = re.compile(r'^street')

CREATED = [ "version", "changeset", "timestamp", "user", "uid"]


def shape_element(element):
    node = {}
    if element.tag == "node" or element.tag == "way" :
        node['type'] = element.tag
        address = {}
        # parsing through attributes
        for a in element.attrib:
            if a in CREATED:
                if 'created' not in node:
                    node['created'] = {}
                node['created'][a] = element.get(a)
            elif a in ['lat', 'lon']:
                continue
            else:
                node[a] = element.get(a)
        if 'lat' in element.attrib and 'lon' in element.attrib:
            node['pos'] = [float(element.get('lat')), float(element.get('lon'))]

        # parse second-level tags for nodes
        for e in element:
            # parse second-level tags for ways and populate `node_refs`
            if e.tag == 'nd':
                if 'node_refs' not in node:
                    node['node_refs'] = []
                if 'ref' in e.attrib:
                    node['node_refs'].append(e.get('ref'))

            # throw out not-tag elements and elements without `k` or `v`
            if e.tag != 'tag' or 'k' not in e.attrib or 'v' not in e.attrib:
                continue
            key = e.get('k')
            val = e.get('v')

            # skip problematic characters
            if problemchars.search(key):
                continue

            # parse address k-v pairs
            elif address_regex.search(key):
                key = key.replace('addr:', '')
                address[key] = val
            # catch-all
            else:
                node[key] = val
        # compile address
        if len(address) > 0:
            node['address'] = {}
            street_full = None
            street_dict = {}
            street_format = ['prefix', 'name', 'type']
            # parse through address objects
            for key in address:
                val = address[key]
                if street_regex.search(key):
                    if key == 'street':
                        street_full = val
                    elif 'street:' in key:
                        street_dict[key.replace('street:', '')] = val
                else:
                    node['address'][key] = val
            # assign street_full or fallback to compile street dict
            if street_full:
                node['address']['street'] = street_full
            elif len(street_dict) > 0:
                node['address']['street'] = ' '.join([street_dict[key] for key in street_format])
        return node
    else:
        return None


def process_map(file_in, pretty = False):
    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in ET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                if pretty:
                    fo.write(json.dumps(el, indent=2)+"\n")
                else:
                    fo.write(json.dumps(el) + "\n")
    return data
process_map(cal_data)
# Out:
# [{'capital': '4',
#   'created': {'changeset': '47074993',
#    'timestamp': '2017-03-22T18:40:18Z',
#    'uid': '2815653',
#    'user': 'Srihari Thalla',
#    'version': '42'},
#   'ele': '8',
#   'id': '16173235',
#   'is_capital': 'state',
#   'is_in:iso_3166_2': 'IN-MH',
#   'name': 'Mumbai',
#   'name:bn': u'\u09ae\u09c1\u09ae\u09cd\u09ac\u0987',
#   'name:cs': 'Bombaj',
#   'name:de': 'Mumbai',
#   'name:en': 'Mumbai',
#   'name:eo': 'Mumbajo',
#   'name:es': 'Bombay',
#   'name:fr': 'Bombay',
#   'name:gu': u'\u0aae\u0ac1\u0a82\u0aac\u0a88',
#   'name:hi': u'\u092e\u0941\u0902\u092c\u0908',
#   'name:ia': 'Mumbai',
#   'name:io': 'Mumbai',
#   'name:ja': u'\u30e0\u30f3\u30d0\u30a4',
#   'name:jbo': '.mumbais.',
#   'name:kn': u'\u0cae\u0cc1\u0c82\u0cac\u0cc8',
#   'name:lt': 'Mumbajus',
#   'name:ml': u'\u0d2e\u0d41\u0d02\u0d2c\u0d48',
#   'name:mr': u'\u092e\u0941\u0902\u092c\u0908',
#   'name:pl': 'Mumbaj',
#   'name:ru': u'\u041c\u0443\u043c\u0431\u0430\u0438',
#   'name:sk': 'Bombaj',
#   'name:sr': u'\u041c\u0443\u043c\u0431\u0430\u0458',
#   'name:ta': u'\u0bae\u0bc1\u0bae\u0bcd\u0baa\u0bc8',
#   'name:te': u'\u0c2e\u0c41\u0c02\u0c2c\u0c48',
#   'name:uk': u'\u041c\u0443\u043c\u0431\u0430\u0457',
#   'name:zh': u'\u5b5f\u4e70',
#   'old_name': 'Bombay',
#   'old_name:eo': 'Bombajo',
#   'old_name:pl': 'Bombaj',
#   'place': 'city',
#   'place:cca': 'a1',
#   'population': '13662885',
#   'pos': [18.9321862, 72.8308337],
#   'rank': '0',
#   'source': 'http://en.wikipedia.org/wiki/Mumbai',
#   'type': 'node',
#   'wikidata': 'Q1156',
#   'wikipedia': 'en:Mumbai'},
#  {'created': {'changeset': '17648476',
#    'timestamp': '2013-09-03T07:13:49Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '17'},
#   'id': '30518346',
#   'pos': [19.0080843, 72.8370034],
#   'type': 'node'},
#  {'created': {'changeset': '30850602',
#    'timestamp': '2015-05-06T18:14:28Z',
#    'uid': '445671',
#    'user': 'flierfy',
#    'version': '15'},
#   'id': '30518350',
#   'pos': [18.9834077, 72.8328729],
#   'type': 'node'},
#  {'created': {'changeset': '7796839',
#    'timestamp': '2011-04-07T18:55:22Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '17'},
#   'id': '30518352',
#   'pos': [18.9666084, 72.8362954],
#   'type': 'node'},
#  {'created': {'changeset': '8772932',
#    'timestamp': '2011-07-19T21:08:33Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '20'},
#   'id': '30518443',
#   'pos': [19.0664744, 72.8808683],
#   'type': 'node'},
#  {'created': {'changeset': '37361001',
#    'timestamp': '2016-02-22T08:04:35Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '19'},
#   'id': '30518455',
#   'pos': [19.0306769, 72.852404],
#   'type': 'node'},
#  {'created': {'changeset': '37266039',
#    'timestamp': '2016-02-17T12:40:01Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '18'},
#   'id': '30518460',
#   'pos': [19.0544393, 72.8688416],
#   'type': 'node'},
#  {'created': {'changeset': '37266039',
#    'timestamp': '2016-02-17T12:40:01Z',
#    'uid': '404532',
#    'user': 'jaimemd',
#    'version': '18'},
#   'id': '30518464',
#   'pos': [19.0622511, 72.8752063],
#   'type': 'node'},
#  {'created': {'changeset': '3225476',
#    'timestamp': '2009-11-27T05:25:15Z',
#    'uid': '17497',
#    'user': 'katpatuka',
#    'version': '2'},
#   'id': '30518508',
#   'pos': [18.8848553, 72.924323],
#   'type': 'node'},
#  {'created': {'changeset': '3225476',
#    'timestamp': '2009-11-27T05:25:15Z',
#    'uid': '17497',
#    'user': 'katpatuka',
#    'version': '3'},
#   'id': '30518509',
#   'pos': [18.8867434, 72.9189264],
#   'type': 'node'},
#  {'created': {'changeset': '545199',
#    'timestamp': '2008-01-05T16:33:11Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '30518510',
#   'pos': [18.8888086, 72.9140003],
#   'type': 'node'},
#  {'created': {'changeset': '12379034',
#    'timestamp': '2012-07-20T14:10:30Z',
#    'uid': '722137',
#    'user': 'OSMF Redaction Account',
#    'version': '5'},
#   'id': '30612776',
#   'pos': [18.8946058, 72.9291917],
#   'type': 'node'},
#  {'created': {'changeset': '2291497',
#    'timestamp': '2009-08-28T16:38:37Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '7'},
#   'id': '206271393',
#   'pos': [19.0626146, 72.8551388],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:45Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272047',
#   'pos': [19.0578233, 72.8219499],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:46Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272048',
#   'pos': [19.0561846, 72.823718],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:46Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272051',
#   'pos': [19.0574339, 72.8226623],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:46Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272054',
#   'pos': [19.0570283, 72.8233404],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:47Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '10'},
#   'id': '206272055',
#   'pos': [19.0444351, 72.8177433],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:47Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272057',
#   'pos': [19.0449458, 72.8185756],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:49Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '7'},
#   'id': '206272059',
#   'pos': [19.0408955, 72.8222019],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:46Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272060',
#   'pos': [19.0543997, 72.8227825],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:49Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206272062',
#   'pos': [19.0429116, 72.8218212],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2291497',
#    'timestamp': '2009-08-28T16:38:37Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272628',
#   'pos': [19.0627054, 72.8553118],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2292233',
#    'timestamp': '2009-08-28T17:26:03Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '4'},
#   'id': '206272817',
#   'pos': [19.0679216, 72.873259],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2292233',
#    'timestamp': '2009-08-28T17:26:03Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272818',
#   'pos': [19.067735, 72.8730444],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2292233',
#    'timestamp': '2009-08-28T17:26:03Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272819',
#   'pos': [19.0680595, 72.8734822],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2292233',
#    'timestamp': '2009-08-28T17:26:04Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '4'},
#   'id': '206272837',
#   'pos': [19.0633544, 72.872375],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2292233',
#    'timestamp': '2009-08-28T17:26:03Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272844',
#   'pos': [19.0668508, 72.8735508],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2292233',
#    'timestamp': '2009-08-28T17:26:03Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '4'},
#   'id': '206272845',
#   'pos': [19.0679378, 72.8736281],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2292233',
#    'timestamp': '2009-08-28T17:26:04Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206272847',
#   'pos': [19.0648958, 72.873259],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2292233',
#    'timestamp': '2009-08-28T17:26:04Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '4'},
#   'id': '206272848',
#   'pos': [19.0663397, 72.8734822],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2291497',
#    'timestamp': '2009-08-28T17:13:12Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '7'},
#   'id': '206272850',
#   'pos': [19.0639125, 72.8726483],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:45Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206273023',
#   'pos': [19.058594, 72.8212032],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:44Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206273039',
#   'pos': [19.0686776, 72.8223533],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:45Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206273045',
#   'pos': [19.0603544, 72.8211946],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:45Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206273046',
#   'pos': [19.0591376, 72.820671],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:45Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206273047',
#   'pos': [19.0589266, 72.8206024],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:44Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206273048',
#   'pos': [19.0673067, 72.8224306],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:45Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206273049',
#   'pos': [19.0581073, 72.8210487],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:50Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '7'},
#   'id': '206276650',
#   'pos': [19.0414269, 72.8229026],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:47Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '10'},
#   'id': '206276653',
#   'pos': [19.0433076, 72.8172421],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:45Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '7'},
#   'id': '206276674',
#   'pos': [19.0580554, 72.8213902],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:47Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '5'},
#   'id': '206276679',
#   'pos': [19.0467706, 72.8193661],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:47Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '7'},
#   'id': '206276681',
#   'pos': [19.0481577, 72.8198624],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:46Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '5'},
#   'id': '206276682',
#   'pos': [19.0498735, 72.8205434],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:46Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '7'},
#   'id': '206276683',
#   'pos': [19.052051, 72.8213079],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:46Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '7'},
#   'id': '206276684',
#   'pos': [19.053861, 72.8220511],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:44Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206276685',
#   'pos': [19.0661791, 72.8228855],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:44Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206276686',
#   'pos': [19.0647351, 72.8229541],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:45Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '7'},
#   'id': '206276687',
#   'pos': [19.062561, 72.8220701],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:45Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206276688',
#   'pos': [19.0617417, 72.8218727],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:44Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '206276690',
#   'pos': [19.0692374, 72.822525],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:43Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276696',
#   'pos': [19.0180761, 72.9285387],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:43Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276697',
#   'pos': [19.0183275, 72.9279942],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:43Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276698',
#   'pos': [19.0172948, 72.9277364],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:44Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276699',
#   'pos': [19.0172887, 72.9271951],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:44Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276701',
#   'pos': [19.0211861, 72.9303948],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:44Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276702',
#   'pos': [19.0206698, 72.9302654],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:44Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276703',
#   'pos': [19.0198886, 72.9294631],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:48Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276746',
#   'pos': [19.0170328, 72.927333],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:48Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276749',
#   'pos': [19.0160032, 72.9273459],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:48Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276750',
#   'pos': [19.0149782, 72.9277651],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:22:48Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206276751',
#   'pos': [19.0148429, 72.9272253],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39496322',
#    'timestamp': '2016-05-22T21:01:02Z',
#    'uid': '3185511',
#    'user': 'JGardke',
#    'version': '10'},
#   'id': '206277359',
#   'pos': [19.0587866, 72.8569781],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '39496322',
#    'timestamp': '2016-05-22T21:01:02Z',
#    'uid': '3185511',
#    'user': 'JGardke',
#    'version': '5'},
#   'id': '206277360',
#   'pos': [19.0583346, 72.8567909],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39496322',
#    'timestamp': '2016-05-22T21:01:02Z',
#    'uid': '3185511',
#    'user': 'JGardke',
#    'version': '10'},
#   'id': '206277361',
#   'pos': [19.0592326, 72.8571605],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '39496322',
#    'timestamp': '2016-05-22T21:01:02Z',
#    'uid': '3185511',
#    'user': 'JGardke',
#    'version': '9'},
#   'id': '206277373',
#   'pos': [19.0572909, 72.8610866],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39496322',
#    'timestamp': '2016-05-22T21:01:03Z',
#    'uid': '3185511',
#    'user': 'JGardke',
#    'version': '9'},
#   'id': '206277375',
#   'pos': [19.0565798, 72.8636919],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39496322',
#    'timestamp': '2016-05-22T21:01:03Z',
#    'uid': '3185511',
#    'user': 'JGardke',
#    'version': '5'},
#   'id': '206277377',
#   'pos': [19.0568916, 72.8624608],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '23951645',
#    'timestamp': '2014-07-04T14:02:02Z',
#    'uid': '1623215',
#    'user': 'ashiwalmukesh',
#    'version': '8'},
#   'id': '206277382',
#   'pos': [19.0570851, 72.8555606],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2292233',
#    'timestamp': '2009-08-28T17:26:02Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '206277444',
#   'pos': [19.0672158, 72.8730874],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39496322',
#    'timestamp': '2016-05-22T21:01:03Z',
#    'uid': '3185511',
#    'user': 'JGardke',
#    'version': '8'},
#   'id': '206277449',
#   'pos': [19.0562285, 72.8655871],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40664946',
#    'timestamp': '2016-07-11T20:21:30Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '206277451',
#   'pos': [19.0565116, 72.866955],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39496322',
#    'timestamp': '2016-05-22T21:01:03Z',
#    'uid': '3185511',
#    'user': 'JGardke',
#    'version': '5'},
#   'id': '206277452',
#   'pos': [19.0561829, 72.8648481],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40664946',
#    'timestamp': '2016-07-11T20:21:30Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'id': '206277454',
#   'pos': [19.0562551, 72.8663768],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39496322',
#    'timestamp': '2016-05-22T21:01:03Z',
#    'uid': '3185511',
#    'user': 'JGardke',
#    'version': '5'},
#   'id': '206277562',
#   'pos': [19.0635623, 72.8719426],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206277916',
#   'pos': [19.0046543, 72.889446],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206277918',
#   'pos': [19.0064934, 72.8893141],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206277922',
#   'pos': [19.0052966, 72.8895926],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206278022',
#   'pos': [19.0129068, 72.8875889],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206278023',
#   'pos': [19.0042385, 72.8927644],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206278026',
#   'pos': [19.0014567, 72.8926911],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:24:59Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278033',
#   'pos': [18.9936072, 72.9046196],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:24:59Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278034',
#   'pos': [18.9948928, 72.9044688],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:24:59Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278035',
#   'pos': [18.9954693, 72.9047359],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:24:59Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278036',
#   'pos': [18.9956034, 72.9049995],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206278037',
#   'pos': [19.013489, 72.8868851],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:25:03Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278071',
#   'pos': [19.0229693, 72.8832747],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:25:03Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278073',
#   'pos': [19.0215717, 72.8849165],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:25:03Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278074',
#   'pos': [19.0200521, 72.8871012],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:25:03Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278079',
#   'pos': [19.0224622, 72.8839574],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:25:03Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278081',
#   'pos': [19.0227212, 72.88409],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206278084',
#   'pos': [19.0152402, 72.8858735],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:25:04Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278086',
#   'pos': [19.0188803, 72.8858974],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:25:04Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206278087',
#   'pos': [19.0201827, 72.8872342],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5484224',
#    'timestamp': '2010-08-13T18:13:50Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '2'},
#   'id': '206280171',
#   'pos': [19.0141825, 72.8810947],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:27Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280173',
#   'pos': [19.0155342, 72.8859398],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206280174',
#   'pos': [19.0145933, 72.8853848],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:28Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280175',
#   'pos': [19.0196541, 72.8860235],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:28Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280177',
#   'pos': [19.0232158, 72.8823238],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:28Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280178',
#   'pos': [19.0226964, 72.8819249],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5484224',
#    'timestamp': '2010-08-13T18:13:51Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '2'},
#   'id': '206280179',
#   'pos': [19.0158054, 72.8815024],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:28Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280180',
#   'pos': [19.0162568, 72.8816],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:28Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280184',
#   'pos': [19.0225579, 72.8811146],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:28Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280185',
#   'pos': [19.0217701, 72.8797712],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206280189',
#   'pos': [19.0087067, 72.8884148],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206280190',
#   'pos': [19.0090209, 72.8869829],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206280191',
#   'pos': [19.0115669, 72.8874276],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206280201',
#   'pos': [19.0035962, 72.8893141],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:30Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280204',
#   'pos': [19.0209257, 72.884654],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:30Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280205',
#   'pos': [19.0219521, 72.8843703],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206280210',
#   'pos': [19.004719, 72.8903306],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206280211',
#   'pos': [19.004756, 72.8897979],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '40607527',
#    'timestamp': '2016-07-09T08:25:42Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206280214',
#   'pos': [19.0148475, 72.8858295],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:31Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280215',
#   'pos': [19.0178569, 72.8864518],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:31Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280216',
#   'pos': [19.0186261, 72.8861713],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:32Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280217',
#   'pos': [19.0163063, 72.8859299],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:32Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280218',
#   'pos': [19.0170848, 72.8864614],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:32Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280219',
#   'pos': [19.0209194, 72.8841127],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:32Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280226',
#   'pos': [19.0039208, 72.8610526],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '3'},
#   'created_by': 'JOSM',
#   'id': '206280227',
#   'pos': [19.0023116, 72.8622015],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:33Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280228',
#   'pos': [19.0065573, 72.8664318],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '206280229',
#   'pos': [19.0032692, 72.8609655],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '206280230',
#   'pos': [19.0060933, 72.8656691],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:33Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280231',
#   'pos': [19.0066917, 72.8669714],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:33Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280232',
#   'pos': [19.0052406, 72.8638771],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '206280233',
#   'pos': [19.0063205, 72.8662441],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '3'},
#   'created_by': 'JOSM',
#   'id': '206280234',
#   'pos': [19.0016461, 72.8610857],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '4'},
#   'created_by': 'JOSM',
#   'id': '206280235',
#   'pos': [18.9956244, 72.8610342],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '3'},
#   'created_by': 'JOSM',
#   'id': '206280237',
#   'pos': [19.000445, 72.8608282],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:33Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280238',
#   'pos': [19.0049567, 72.8615807],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:34Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280239',
#   'pos': [19.0049504, 72.8610394],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:34Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280240',
#   'pos': [19.0045826, 72.862668],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '206280241',
#   'pos': [19.0049572, 72.8622873],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '206280242',
#   'pos': [19.0026037, 72.8611115],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:34Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280243',
#   'pos': [19.007618, 72.8691248],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:34Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280244',
#   'pos': [19.0107223, 72.8704384],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:34Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280245',
#   'pos': [19.0091812, 72.8707287],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:34Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280246',
#   'pos': [19.0069523, 72.8672388],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:34Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280247',
#   'pos': [19.0099221, 72.8680127],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:34Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280248',
#   'pos': [19.0097992, 72.8685556],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:34Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280249',
#   'pos': [19.0103203, 72.8690902],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:35Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280251',
#   'pos': [19.0104369, 72.8680061],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '206280252',
#   'pos': [19.0051357, 72.8634976],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:35Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280253',
#   'pos': [19.0092645, 72.8703639],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5484224',
#    'timestamp': '2010-08-13T18:13:50Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '2'},
#   'id': '206280254',
#   'pos': [19.0138477, 72.879818],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:35Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280256',
#   'pos': [19.012112, 72.8793524],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5484224',
#    'timestamp': '2010-08-13T18:13:51Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '2'},
#   'id': '206280257',
#   'pos': [19.0176211, 72.8813736],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5484224',
#    'timestamp': '2010-08-13T18:13:51Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '2'},
#   'id': '206280258',
#   'pos': [19.0170328, 72.8817813],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:35Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280259',
#   'pos': [19.0116384, 72.8717801],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:35Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280260',
#   'pos': [19.0113842, 72.8720539],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5484224',
#    'timestamp': '2010-08-13T18:13:50Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '2'},
#   'id': '206280261',
#   'pos': [19.0136043, 72.8808908],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5484224',
#    'timestamp': '2010-08-13T18:13:50Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '2'},
#   'id': '206280262',
#   'pos': [19.0137463, 72.8803544],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:36Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280266',
#   'pos': [19.0114978, 72.8706992],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:36Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280267',
#   'pos': [19.0086444, 72.8688409],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:36Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280268',
#   'pos': [19.0094182, 72.8689661],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:36Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280272',
#   'pos': [19.0109036, 72.8750373],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:36Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280273',
#   'pos': [19.0112653, 72.8728674],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:37Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280274',
#   'pos': [19.0087758, 72.8691101],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:37Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280275',
#   'pos': [19.0116883, 72.8761099],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:37Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280278',
#   'pos': [19.01178, 72.8728608],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:37Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280279',
#   'pos': [19.0113872, 72.8723246],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '20197155',
#    'timestamp': '2014-01-25T17:35:52Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '206280288',
#   'pos': [18.9745426, 72.8553362],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '4456002',
#    'timestamp': '2010-04-18T09:56:54Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '206280292',
#   'pos': [18.9766719, 72.8553365],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '4456002',
#    'timestamp': '2010-04-18T09:56:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '206280294',
#   'pos': [18.9777727, 72.8556313],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39870586',
#    'timestamp': '2016-06-07T20:09:23Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '2'},
#   'id': '206280301',
#   'pos': [18.9731705, 72.8540803],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:39Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280302',
#   'pos': [18.9737212, 72.8541324],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39870586',
#    'timestamp': '2016-06-07T20:09:23Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '5'},
#   'id': '206280303',
#   'pos': [18.9721611, 72.8534773],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '39870586',
#    'timestamp': '2016-06-07T20:09:23Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '206280304',
#   'pos': [18.9726959, 72.8540503],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2816346',
#    'timestamp': '2009-10-11T17:39:06Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '2'},
#   'id': '206280322',
#   'pos': [18.9933759, 72.8575968],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '4456671',
#    'timestamp': '2010-04-18T11:17:31Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '5'},
#   'id': '206280323',
#   'pos': [18.9919087, 72.8568759],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '4'},
#   'created_by': 'JOSM',
#   'id': '206280324',
#   'pos': [18.9946505, 72.8603132],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '4'},
#   'created_by': 'JOSM',
#   'id': '206280325',
#   'pos': [18.9947723, 72.8589056],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '2816346',
#    'timestamp': '2009-10-11T17:39:07Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '2'},
#   'id': '206280326',
#   'pos': [18.9943417, 72.8582062],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '4456671',
#    'timestamp': '2010-04-18T11:17:20Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '3'},
#   'id': '206280328',
#   'pos': [18.9939245, 72.8563763],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '4456671',
#    'timestamp': '2010-04-18T11:17:18Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '206280331',
#   'pos': [18.9982293, 72.8600507],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '3'},
#   'created_by': 'JOSM',
#   'id': '206280332',
#   'pos': [19.002133, 72.8611973],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '3'},
#   'created_by': 'JOSM',
#   'id': '206280333',
#   'pos': [19.0019058, 72.8621843],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:44Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280347',
#   'pos': [19.008782, 72.8696512],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:44Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280348',
#   'pos': [19.0094386, 72.8707255],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '555726',
#    'timestamp': '2008-01-06T01:59:50Z',
#    'uid': '1164',
#    'user': 'dmgroom',
#    'version': '2'},
#   'created_by': 'JOSM',
#   'id': '206280351',
#   'pos': [19.0061095, 72.8650683],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:44Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280352',
#   'pos': [19.0048431, 72.8629353],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:44Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280353',
#   'pos': [19.0094354, 72.8704548],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '545532',
#    'timestamp': '2008-01-05T15:44:44Z',
#    'uid': '4772',
#    'user': 'dmgroom_coastlines',
#    'version': '1'},
#   'created_by': 'JOSM',
#   'id': '206280354',
#   'pos': [19.0078771, 72.8692564],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '15133451',
#    'timestamp': '2013-02-23T10:53:59Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '206280417',
#   'pos': [18.9756284, 72.8558788],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '49586596',
#    'timestamp': '2017-06-16T10:05:49Z',
#    'uid': '3786471',
#    'user': 'Zulfiqarib',
#    'version': '12'},
#   'id': '206280432',
#   'pos': [18.9778411, 72.8075229],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '38835163',
#    'timestamp': '2016-04-24T15:15:02Z',
#    'uid': '3786471',
#    'user': 'Zulfiqarib',
#    'version': '11'},
#   'id': '206280433',
#   'pos': [18.9781667, 72.8069922],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:50Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '5'},
#   'id': '206280434',
#   'pos': [19.042579, 72.8250312],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:51Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '3'},
#   'id': '206280435',
#   'pos': [19.0435497, 72.8267074],
#   'source': 'PGS',
#   'type': 'node'},
#  {'created': {'changeset': '5528962',
#    'timestamp': '2010-08-18T18:07:50Z',
#    'uid': '99655',
# ...
#  {'created': {'changeset': '15188347',
#    'timestamp': '2013-02-27T17:37:32Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '245654001',
#   'pos': [18.9316202, 72.8228391],
#   'type': 'node'},
#  {'created': {'changeset': '10760155',
#    'timestamp': '2012-02-22T15:27:47Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '10'},
#   'id': '245654003',
#   'pos': [18.9306945, 72.8313575],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '10759780',
#    'timestamp': '2012-02-22T14:44:40Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '5'},
#   'id': '245654004',
#   'pos': [18.93075, 72.8339943],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:53Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '245654005',
#   'pos': [18.9307399, 72.8348749],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '234764',
#    'timestamp': '2008-12-07T10:46:48Z',
#    'uid': '308',
#    'user': 'MichaelCollinson',
#    'version': '4'},
#   'id': '245654011',
#   'pos': [18.9309859, 72.834917],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15131810',
#    'timestamp': '2013-02-23T07:34:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '245654021',
#   'pos': [18.9313382, 72.8331014],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '10759780',
#    'timestamp': '2012-02-22T14:44:40Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '245654022',
#   'pos': [18.9311827, 72.8340599],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:53Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '10'},
#   'id': '245654023',
#   'pos': [18.9313759, 72.835218],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '4455244',
#    'timestamp': '2010-04-18T08:38:07Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '245654026',
#   'pos': [18.9290575, 72.8433162],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '2391560',
#    'timestamp': '2009-09-06T15:15:40Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '5'},
#   'id': '245654031',
#   'pos': [18.9314407, 72.832584],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:53Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'id': '245654036',
#   'pos': [18.931344, 72.8349384],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '42552891',
#    'timestamp': '2016-09-30T21:28:55Z',
#    'uid': '145231',
#    'user': 'woodpeck_repair',
#    'version': '4'},
#   'id': '245654039',
#   'pos': [18.9316901, 72.8298427],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '9341383',
#    'timestamp': '2011-09-19T10:56:20Z',
#    'uid': '28466',
#    'user': 'shekhar',
#    'version': '5'},
#   'id': '245654040',
#   'pos': [18.9317479, 72.8308313],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '10760155',
#    'timestamp': '2012-02-22T15:27:48Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '245654041',
#   'pos': [18.9318805, 72.8313162],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '10759780',
#    'timestamp': '2012-02-22T14:44:41Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'id': '245654042',
#   'pos': [18.931634, 72.8317164],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '9341545',
#    'timestamp': '2011-09-19T11:12:28Z',
#    'uid': '28466',
#    'user': 'shekhar',
#    'version': '8'},
#   'id': '245654047',
#   'pos': [18.931731, 72.8273439],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:54Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'id': '245654056',
#   'pos': [18.932055, 72.8343574],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '8839187',
#    'timestamp': '2011-07-26T21:31:54Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '245654061',
#   'pos': [18.9322586, 72.8275153],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15176890',
#    'timestamp': '2013-02-26T18:48:51Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '5'},
#   'id': '245654062',
#   'pos': [18.93209, 72.8282621],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '42552891',
#    'timestamp': '2016-09-30T21:28:55Z',
#    'uid': '145231',
#    'user': 'woodpeck_repair',
#    'version': '7'},
#   'id': '245654063',
#   'pos': [18.9320798, 72.8297728],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '40793201',
#    'timestamp': '2016-07-17T08:20:22Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '11'},
#   'id': '245654066',
#   'pos': [18.9321713, 72.8332363],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '42552891',
#    'timestamp': '2016-09-30T21:28:56Z',
#    'uid': '145231',
#    'user': 'woodpeck_repair',
#    'version': '5'},
#   'id': '245654071',
#   'pos': [18.9323255, 72.8296814],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '40793201',
#    'timestamp': '2016-07-17T08:20:22Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'id': '245654072',
#   'pos': [18.9322701, 72.8326108],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:54Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'id': '245654073',
#   'pos': [18.9323951, 72.8345372],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '40793201',
#    'timestamp': '2016-07-17T08:20:22Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '10'},
#   'id': '245654077',
#   'pos': [18.932388, 72.8318345],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '42552891',
#    'timestamp': '2016-09-30T21:28:56Z',
#    'uid': '145231',
#    'user': 'woodpeck_repair',
#    'version': '5'},
#   'id': '245654081',
#   'pos': [18.9324879, 72.8295698],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:54Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '10'},
#   'id': '245654082',
#   'pos': [18.9326047, 72.8351415],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15188347',
#    'timestamp': '2013-02-27T17:37:32Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '12'},
#   'id': '245654083',
#   'pos': [18.9321341, 72.8357815],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '42552891',
#    'timestamp': '2016-09-30T21:28:53Z',
#    'uid': '145231',
#    'user': 'woodpeck_repair',
#    'version': '11'},
#   'highway': 'traffic_signals',
#   'id': '245654088',
#   'pos': [18.9326292, 72.830007],
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:54Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'id': '245654092',
#   'pos': [18.9325564, 72.8353657],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '42552891',
#    'timestamp': '2016-09-30T21:28:56Z',
#    'uid': '145231',
#    'user': 'woodpeck_repair',
#    'version': '8'},
#   'id': '245654098',
#   'pos': [18.932706, 72.8293656],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '10759906',
#    'timestamp': '2012-02-22T14:59:56Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '245654103',
#   'pos': [18.9327874, 72.8285778],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15132315',
#    'timestamp': '2013-02-23T08:52:39Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '245654104',
#   'pos': [18.9328769, 72.8327431],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '10759906',
#    'timestamp': '2012-02-22T14:59:56Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '245654105',
#   'pos': [18.9330153, 72.8320807],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15188347',
#    'timestamp': '2013-02-27T17:37:32Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '245654107',
#   'pos': [18.932641, 72.8232544],
#   'type': 'node'},
#  {'created': {'changeset': '15176890',
#    'timestamp': '2013-02-26T18:48:51Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '12'},
#   'highway': 'traffic_signals',
#   'id': '245654108',
#   'pos': [18.932868, 72.8279897],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '42552891',
#    'timestamp': '2016-09-30T21:28:27Z',
#    'uid': '145231',
#    'user': 'woodpeck_repair',
#    'version': '10'},
#   'id': '245654110',
#   'pos': [18.9331226, 72.8316013],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15135545',
#    'timestamp': '2013-02-23T13:55:17Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '245654111',
#   'pos': [18.9330505, 72.8328251],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15122912',
#    'timestamp': '2013-02-22T12:43:29Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '245654112',
#   'pos': [18.9329153, 72.833454],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:54Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '245654113',
#   'pos': [18.9324398, 72.8358667],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '10759906',
#    'timestamp': '2012-02-22T14:59:56Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '245654116',
#   'pos': [18.9330596, 72.8271366],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '2812305',
#    'timestamp': '2009-10-11T11:25:53Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '5'},
#   'id': '245654120',
#   'pos': [18.9333254, 72.8345652],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '245654124',
#   'pos': [18.9333736, 72.8352539],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '4064643',
#    'timestamp': '2010-03-07T19:05:39Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '8'},
#   'id': '245654127',
#   'pos': [18.9334605, 72.8345814],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15188347',
#    'timestamp': '2013-02-27T17:37:32Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'highway': 'traffic_signals',
#   'id': '245654132',
#   'pos': [18.9336496, 72.8235863],
#   'type': 'node'},
#  {'created': {'changeset': '10760102',
#    'timestamp': '2012-02-22T15:20:56Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '4'},
#   'id': '245654133',
#   'pos': [18.93345, 72.8335798],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '10760102',
#    'timestamp': '2012-02-22T15:20:56Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '10'},
#   'id': '245654135',
#   'pos': [18.9336055, 72.8346017],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15127904',
#    'timestamp': '2013-02-22T19:52:43Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '5'},
#   'id': '245654139',
#   'pos': [18.9335512, 72.8329489],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '9341545',
#    'timestamp': '2011-09-19T11:12:29Z',
#    'uid': '28466',
#    'user': 'shekhar',
#    'version': '4'},
#   'id': '245654143',
#   'pos': [18.9340737, 72.8270909],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15122912',
#    'timestamp': '2013-02-22T12:43:29Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '9'},
#   'id': '245654148',
#   'pos': [18.9338543, 72.8336736],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '5'},
#   'id': '245654149',
#   'pos': [18.9336365, 72.8358546],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '245654150',
#   'pos': [18.9334882, 72.8369534],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '4074616',
#    'timestamp': '2010-03-08T19:01:25Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '6'},
#   'id': '245654151',
#   'pos': [18.9339525, 72.8397727],
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '245654154',
#   'pos': [18.9336745, 72.8366028],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '4319129',
#    'timestamp': '2010-04-04T06:11:30Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '5'},
#   'id': '245654158',
#   'pos': [18.934265, 72.8287426],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15097203',
#    'timestamp': '2013-02-20T08:49:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '245654159',
#   'pos': [18.9339812, 72.8346774],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:58Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '245654160',
#   'pos': [18.9338717, 72.8353392],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '4060527',
#    'timestamp': '2010-03-07T12:46:48Z',
#    'uid': '99655',
#    'user': 'MJL Wood',
#    'version': '3'},
#   'id': '245654161',
#   'pos': [18.9341185, 72.8389331],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15176890',
#    'timestamp': '2013-02-26T18:48:52Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '6'},
#   'id': '245654163',
#   'pos': [18.9340793, 72.8278342],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:58Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '245654164',
#   'pos': [18.9340181, 72.835829],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '11205571',
#    'timestamp': '2012-04-06T18:46:58Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '5'},
#   'id': '245654166',
#   'pos': [18.9342197, 72.836327],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15178103',
#    'timestamp': '2013-02-26T20:32:00Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '245654167',
#   'pos': [18.9343507, 72.8401203],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '7922663',
#    'timestamp': '2011-04-21T07:09:28Z',
#    'uid': '439726',
#    'user': 'chandusekharreddy',
#    'version': '6'},
#   'id': '245654168',
#   'pos': [18.9342143, 72.8406485],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15131810',
#    'timestamp': '2013-02-23T07:34:27Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '8'},
#   'id': '245654171',
#   'pos': [18.9341184, 72.8354108],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15096988',
#    'timestamp': '2013-02-20T08:30:01Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'highway': 'traffic_signals',
#   'id': '245654172',
#   'pos': [18.9344956, 72.837098],
#   'type': 'node'},
#  {'created': {'changeset': '15097203',
#    'timestamp': '2013-02-20T08:49:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '245654174',
#   'pos': [18.9342419, 72.8337887],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '15097203',
#    'timestamp': '2013-02-20T08:49:57Z',
#    'uid': '1306',
#    'user': 'PlaneMad',
#    'version': '7'},
#   'id': '245654175',
#   'pos': [18.9343389, 72.834727],
#   'source': 'AND',
#   'type': 'node'},
#  {'created': {'changeset': '32844216',
#    'timestamp': '2015-07-24T08:49:28Z',
#    'uid': '2897465',
#    'user': 'maheshrkm',
#    'version': '8'},
#   'id': '245654178',
#   'pos': [18.9345786, 72.8390385],
#   'source': 'AND',
#   'type': 'node'},
#  ...]

# %% [markdown]
# <h2><a name="data_overview"></a> **3. Data Overview with MongoDB**</h2>

# %%
import signal
import subprocess
pro = subprocess.Popen('mongod')#, preexec_fn = os.setsid)

# %%
from pymongo import MongoClient
db_name = 'openstreetmap'

# Connect to Mongo DB
client = MongoClient('localhost:27017')
db = client[db_name]

# %%
# Build mongoimport command
collection = cal_data[:cal_data.find('.')]
json_file = cal_data + '.json'

mongoimport_cmd = 'mongoimport -h 127.0.0.1:27017 ' + '--db ' + db_name + ' --collection ' + collection + ' --file ' + json_file

# Before importing, drop collection if it is already running 
if collection in db.collection_names():
    print 'Dropping collection: ' + collection
    db[collection].drop()
    
# Execute the command
print 'Executing: ' + mongoimport_cmd
subprocess.call(mongoimport_cmd.split())
# Out:
# Executing: mongoimport -h 127.0.0.1:27017 --db openstreetmap --collection data\mumbai --file data\mumbai.osm.json
# 0

# %%
mumbai = db[collection]

# %% [markdown]
# #### File sizes

# %%
import os
print 'The original OSM file is {} MB'.format(os.path.getsize(cal_data)/1.0e6) # convert from bytes to mb
print 'The JSON file is {} MB'.format(os.path.getsize(cal_data + ".json")/1.0e6) # convert from bytes to mb
# Out:
# The original OSM file is 56.364893 MB
# The JSON file is 65.88346 MB

# %% [markdown]
# #### Number of documents

# %%
mumbai.find().count()
# Out:
# 303290

# %% [markdown]
# #### Number of unique users

# %%
len(mumbai.distinct('created.user'))
# Out:
# 778

# %% [markdown]
# #### Number of Nodes and Ways

# %%
print "Number of nodes:",mumbai.find({'type':'node'}).count()
print "Number of ways:",mumbai.find({'type':'way'}).count()
# Out:
# Number of nodes: 262990
# Number of ways: 40191

# %% [markdown]
# #### Name of top 5 contributors

# %%
result = mumbai.aggregate( [
                                        { "$group" : {"_id" : "$created.user", 
                                        "count" : { "$sum" : 1} } },
                                        { "$sort" : {"count" : -1} }, 
                                        { "$limit" : 5 } ] )
pprint.pprint(list(result))
# Out:
# [{u'_id': u'PlaneMad', u'count': 31353},
#  {u'_id': u'anthony1', u'count': 18584},
#  {u'_id': u'Zulfiqarib', u'count': 16677},
#  {u'_id': u'Nagarjunreddy', u'count': 15081},
#  {u'_id': u'venkatkotha', u'count': 14686}]

# %% [markdown]
# <h2><a name="exploration"></a> **4. Further data explaration with MongoDB**</h2>

# %% [markdown]
# #### List of top 20 amenities in Mumbai

# %%
amenity = mumbai.aggregate([{'$match': {'amenity': {'$exists': 1}}}, \
                                {'$group': {'_id': '$amenity', \
                                            'count': {'$sum': 1}}}, \
                                {'$sort': {'count': -1}}, \
                                {'$limit': 10}])
pprint.pprint(list(amenity))
# Out:
# [{u'_id': u'place_of_worship', u'count': 207},
#  {u'_id': u'restaurant', u'count': 199},
#  {u'_id': u'bank', u'count': 125},
#  {u'_id': u'school', u'count': 117},
#  {u'_id': u'hospital', u'count': 75},
#  {u'_id': u'cafe', u'count': 57},
#  {u'_id': u'college', u'count': 51},
#  {u'_id': u'parking', u'count': 49},
#  {u'_id': u'police', u'count': 43},
#  {u'_id': u'fuel', u'count': 43}]

# %% [markdown]
# #### List of top 5 Foods in Mumbai

# %%
cuisine = mumbai.aggregate([{"$match":{"amenity":{"$exists":1},
                                 "amenity":"restaurant",}},      
                      {"$group":{"_id":{"Food":"$cuisine"},
                                 "count":{"$sum":1}}},
                      {"$project":{"_id":0,
                                  "Food":"$_id.Food",
                                  "Count":"$count"}},
                      {"$sort":{"Count":-1}}, 
                      {"$limit":6}])
pprint.pprint(list(cuisine))
# Out:
# [{u'Count': 115, u'Food': None},
#  {u'Count': 29, u'Food': u'indian'},
#  {u'Count': 7, u'Food': u'pizza'},
#  {u'Count': 6, u'Food': u'vegetarian'},
#  {u'Count': 5, u'Food': u'regional'},
#  {u'Count': 4, u'Food': u'italian'}]

# %% [markdown]
# #### List of top 10 post code in Mumbai

# %%
postcode = mumbai.aggregate( [ 
    { "$match" : { "address.postcode" : { "$exists" : 1} } }, 
    { "$group" : { "_id" : "$address.postcode", "count" : { "$sum" : 1} } },  
    { "$sort" : { "count" : -1}},
      {"$limit":10}] )
pprint.pprint(list(postcode))
# Out:
# [{u'_id': u'400050', u'count': 635},
#  {u'_id': u'400043', u'count': 81},
#  {u'_id': u'400005', u'count': 79},
#  {u'_id': u'400089', u'count': 54},
#  {u'_id': u'400074', u'count': 42},
#  {u'_id': u'400071', u'count': 38},
#  {u'_id': u'400001', u'count': 30},
#  {u'_id': u'400002', u'count': 28},
#  {u'_id': u'400051', u'count': 22},
#  {u'_id': u'400004', u'count': 21}]

# %% [markdown]
# #### Total users have unique post (post only one time)

# %%
users = mumbai.aggregate( [
    { "$group" : {"_id" : "$created.user", 
                "count" : { "$sum" : 1} } },
    { "$group" : {"_id" : "$count",
                "num_users": { "$sum" : 1} } },
    { "$sort" : {"_id" : 1} },
    { "$limit" : 1} ] )
print(list(users))
# Out:
# [{u'num_users': 195, u'_id': 1}]

# %%
building = mumbai.aggregate([
       {'$match': {'building': { '$exists': 1}}}, 
        {'$group': {'_id': '$building',
                    'count': {'$sum': 1}}}, 
        {'$sort': {'count': -1}},
        {'$limit': 5}])
pprint.pprint(list(building))
# Out:
# [{u'_id': u'yes', u'count': 26328},
#  {u'_id': u'apartments', u'count': 387},
#  {u'_id': u'residential', u'count': 250},
#  {u'_id': u'commercial', u'count': 76},
#  {u'_id': u'house', u'count': 69}]

# %% [markdown]
# <h2><a name="conclusion"></a> **4. Conclusion**</h2>

# %% [markdown]
# **_Ideas to improve data quality of OSM:_**
#
# While auditing the data, we find that although there are minor human input errors, the dataset is fairly clean. For human errors we can have a srtuctured input form so everyone can input the same data format to reduce errors. Moreover, we can incentivize users in the contribution process, then we can create a recommendation engine to leverage this data, since OpenStreetMaps is an open source project, there're still a lot of areas left unexplored as people tend to focus on a certain key areas and left other part outdated. we can resolve this issue by cross-referencing/cross-validating missing data from other database like Google API. Since each node has a coordinate (lattitude & longtitude).
#
# **_Potential cost of the implementation:_**
#
# There're few potential issues that may arise from the implementation of this solution. One of which is the amount of effort to engineer all this and the cost of creating, auditing & maintaining thus may require a dedicated team.

# %% [markdown]
# **References:**
#
# Udacity "Data Wrangling with MongoDB"
#
# <a href=https://docs.mongodb.org/manual/reference/program/mongoimport/> MongoDB Importing XML to JSON Guide </a>
